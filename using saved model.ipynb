# %%
import tensorflow as tf

# %%
print('num gpu:',len(tf.config.list_logical_devices('GPU')))
# Out:
# num gpu: 0

# %%
from tensorflow.keras.models import load_model

model = load_model("cat_dog_vgg16.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
img_path = r"C:\Users\Ashish yadav\100DL\11.dog vs cat on pretrained model\test\dogs\dog.1.jpg"   # put your image path here

img = image.load_img(img_path, target_size=(224,224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img / 255.0
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 img_path = r"C:\Users\Ashish yadav\100DL\11.dog vs cat on pretrained model\test\dogs\dog.388.jpg"   # put your image path here
# ----> 3 img = image.load_img(img_path, target_size=(224,224))
#       4 img = image.img_to_array(img)
#       5 img = np.expand_dims(img, axis=0)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Ashish yadav\\100DL\\11.dog vs cat on pretrained model\\test\\dogs\\dog.388.jpg'

# %%
prediction = model.predict(img)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# [[0.9533775]]

# %%
if prediction[0][0] > 0.5:
    print("Dog 🐶")
else:
    print("Cat 🐱")
# Out:
# Dog 🐶
